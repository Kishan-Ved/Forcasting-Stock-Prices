# %%
import pandas as pd
df = pd.read_csv('/content/train.csv')
df
# Out:
#              dates  Factor A  Factor B  Factor C  Factor D  Factor E  \
# 0       1700-01-01    502.52    498.78    493.98     947.6    505.24
# 1       1700-01-02    503.33    495.09    496.93     928.6    506.21
# 2       1700-01-03    500.62    493.71    504.75     935.5    505.51
# 3       1700-01-04    502.08    492.98    502.20     923.5    505.25
# 4       1700-01-05    502.81    493.23    499.57     918.1    504.86
# ...            ...       ...       ...       ...       ...       ...
# 161763  2142-11-23  10499.99  10499.99  10499.99  100499.9   1499.99
# 161764  2142-11-24  10499.99  10499.99  10499.99  100499.9   1499.99
# 161765  2142-11-25  10499.99  10499.99  10499.99  100499.9   1499.99
# 161766  2142-11-26  10499.99  10499.99  10499.99  100499.9   1499.99
# 161767  2142-11-27  10499.99  10499.99  10499.99  100499.9   1499.99
#
#           Factor F  Factor G  Factor H  Factor I  Factor J  Factor K  \
# ...

# %%
import numpy as np
ndf = df.iloc[:,np.arange(1,15)]
ndf
# Out:
#         Factor A  Factor B  Factor C  Factor D  Factor E    Factor F  \
# 0         502.52    498.78    493.98     947.6    505.24     79050.0
# 1         503.33    495.09    496.93     928.6    506.21     31082.0
# 2         500.62    493.71    504.75     935.5    505.51     19375.0
# 3         502.08    492.98    502.20     923.5    505.25     22010.0
# 4         502.81    493.23    499.57     918.1    504.86     26533.0
# ...          ...       ...       ...       ...       ...         ...
# 161763  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 161764  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 161765  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 161766  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 161767  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
#
#         Factor G  Factor H  Factor I  Factor J  Factor K  Factor L  Factor M  \
# ...

# %% [markdown]
# #Important observation
# Several rows are exactly the same in the correlation matrix, and hence can be dropped to save computation time, as the dataset is too large.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
corr_matrix = ndf.corr()

# Plot the correlation matrix as a heatmap
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)

# Show the plot
plt.show()

# %%
d = ndf.iloc[:,[0,3,5,6,7]]
d
# Out:
#         Factor A  Factor D    Factor F  Factor G  Factor H
# 0         502.52     947.6     79050.0    502.10    502.73
# 1         503.33     928.6     31082.0    502.28    501.96
# 2         500.62     935.5     19375.0    502.09    499.17
# 3         502.08     923.5     22010.0    501.88    500.43
# 4         502.81     918.1     26533.0    501.70    501.46
# ...          ...       ...         ...       ...       ...
# 161763  10499.99  100499.9  10000500.0    599.99   1499.99
# 161764  10499.99  100499.9  10000500.0    599.99   1499.99
# 161765  10499.99  100499.9  10000500.0    599.99   1499.99
# 161766  10499.99  100499.9  10000500.0    599.99   1499.99
# 161767  10499.99  100499.9  10000500.0    599.99   1499.99
#
# [161768 rows x 5 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
corr_matrix = d.corr()

# Plot the correlation matrix as a heatmap
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)

# Show the plot
plt.show()

# %%
train = d[0:-1000]
train
# Out:
#         Factor A  Factor D    Factor F  Factor G  Factor H
# 0         502.52     947.6     79050.0    502.10    502.73
# 1         503.33     928.6     31082.0    502.28    501.96
# 2         500.62     935.5     19375.0    502.09    499.17
# 3         502.08     923.5     22010.0    501.88    500.43
# 4         502.81     918.1     26533.0    501.70    501.46
# ...          ...       ...         ...       ...       ...
# 161763  10499.99  100499.9  10000500.0    599.99   1499.99
# 161764  10499.99  100499.9  10000500.0    599.99   1499.99
# 161765  10499.99  100499.9  10000500.0    599.99   1499.99
# 161766  10499.99  100499.9  10000500.0    599.99   1499.99
# 161767  10499.99  100499.9  10000500.0    599.99   1499.99
#
# [161768 rows x 5 columns]

# %%
test = d[-1000:]
test
# Out:
#         Factor A  Factor D    Factor F  Factor G  Factor H
# 160768    500.39     812.1     16463.0    502.68    499.95
# 160769    500.71     824.6     18922.0    502.49    499.82
# 160770    502.05     825.4     32993.0    501.65    499.21
# 160771    503.41     827.6     38121.0    501.40    499.25
# 160772    503.24     824.6     42987.0    501.62    499.41
# ...          ...       ...         ...       ...       ...
# 161763  10499.99  100499.9  10000500.0    599.99   1499.99
# 161764  10499.99  100499.9  10000500.0    599.99   1499.99
# 161765  10499.99  100499.9  10000500.0    599.99   1499.99
# 161766  10499.99  100499.9  10000500.0    599.99   1499.99
# 161767  10499.99  100499.9  10000500.0    599.99   1499.99
#
# [1000 rows x 5 columns]

# %%
target1 = df.iloc[:,15]
target1
# Out:
# 0         519.0
# 1         518.0
# 2         523.0
# 3         522.0
# 4         522.0
#           ...
# 161763    498.0
# 161764    502.0
# 161765    508.0
# 161766    507.0
# 161767    499.0
# Name: TGD Consultancy Share price, Length: 161768, dtype: float64

# %%
target2 = df.iloc[:,16]
target2
# Out:
# 0         420.0
# 1         420.0
# 2         437.0
# 3         437.0
# 4         437.0
#           ...
# 161763    420.0
# 161764    420.0
# 161765    420.0
# 161766    420.0
# 161767    420.0
# Name: TGD Automobiles Share price, Length: 161768, dtype: float64

# %%
target3 = df.iloc[:,17]
target3
# Out:
# 0         507.0
# 1         507.0
# 2         522.0
# 3         522.0
# 4         522.0
#           ...
# 161763    507.0
# 161764    507.0
# 161765    507.0
# 161766    507.0
# 161767    507.0
# Name: TGD Power Share price, Length: 161768, dtype: float64

# %% [markdown]
# Several models were tried out for the 3 target vectors that had to be predicted. The models are -
#
# Logistic Regression for TGD Consultancy Share Price
#
# XG Boost Regression for TGD Automobiles Share Price
#
# Logistic Regression for TGD Power Share Price

# %% [markdown]
# #Observation - Minimum Errors on a part of training data

# %% [markdown]
# After testing a plethora of models, we arrived at the following 2 best fitting solutions.

# %% [markdown]
# # Testing Logistic Regression model for TGD Consultancy Share Price

# %%
# Takes 4 minutes, run if needed

# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import mean_squared_error

# model = LogisticRegression()
# model.fit(train,target1[0:-1000])
# y_model = model.predict(test)
# mean_squared_error(target1[-1000:],y_model)**0.5
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 8.696781013685467

# %% [markdown]
# # Testing XG Boost model for TGD Automobiles Share Price

# %%
# Takes 2 minutes, run if needed

# import xgboost as xgb

# model = xgb.XGBRegressor()
# model.fit(train,target2[0:-1000])
# y_model = model.predict(test)
# mean_squared_error(target2[-1000:],y_model)**0.5
# Out:
# 10.867322533607197

# %% [markdown]
# # Testing Logistic Regression model for TGD Power Share Price

# %%
# Takes 4 minutes, run if needed

# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import mean_squared_error

# model = LogisticRegression()
# model.fit(train,target3[0:-1000])
# y_model = model.predict(test)
# mean_squared_error(target3[-1000:],y_model)**0.5
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 6.78314086541036

# %%
train = d[:]
train
# Out:
#         Factor A  Factor D    Factor F  Factor G  Factor H
# 0         502.52     947.6     79050.0    502.10    502.73
# 1         503.33     928.6     31082.0    502.28    501.96
# 2         500.62     935.5     19375.0    502.09    499.17
# 3         502.08     923.5     22010.0    501.88    500.43
# 4         502.81     918.1     26533.0    501.70    501.46
# ...          ...       ...         ...       ...       ...
# 161763  10499.99  100499.9  10000500.0    599.99   1499.99
# 161764  10499.99  100499.9  10000500.0    599.99   1499.99
# 161765  10499.99  100499.9  10000500.0    599.99   1499.99
# 161766  10499.99  100499.9  10000500.0    599.99   1499.99
# 161767  10499.99  100499.9  10000500.0    599.99   1499.99
#
# [161768 rows x 5 columns]

# %% [markdown]
# #Final Model

# %%
import pandas as pd
df = pd.read_csv('/content/test.csv')
ndf = df.iloc[:,np.arange(1,15)]
test = ndf.iloc[:,[0,3,5,6,7]]

model = LogisticRegression()
model.fit(train,target1)
y_model1 = model.predict(test)
y_model1 # Converging error but final array is returned
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:450: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   opt_res = optimize.minimize(
# array([508., 508., 508., ..., 508., 508., 508.])

# %%
model = xgb.XGBRegressor()
model.fit(train,target2)
y_model2 = model.predict(test)
y_model2
# Out:
# array([417.98288, 417.98288, 417.98288, ..., 420.5201 , 416.39923,
#        416.4249 ], dtype=float32)

# %%
model = LogisticRegression()
model.fit(train,target3)
y_model3 = model.predict(test)
y_model3 # Converging error but final array is returned
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:450: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   opt_res = optimize.minimize(
# array([503., 503., 503., ..., 503., 503., 503.])
